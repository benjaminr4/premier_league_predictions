# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import KFold
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
pd.set_option('display.max_columns', None)
#pd.reset_option('display.max_columns')

# %%
seasons_df=pd.read_pickle('data/seasons_betting_df.pkl')

# %%
#seasons_df=pd.get_dummies(seasons_df, columns=['HomeTeam', 'AwayTeam'])
seasons_df.drop(columns=['HomeTeam', 'AwayTeam'], inplace=True)

# %%
pd.set_option('future.no_silent_downcasting', True)
seasons_df=seasons_df.fillna(0)

# %%
label_encoder = LabelEncoder()
seasons_df['label'] = label_encoder.fit_transform(seasons_df['FTR'])

# %%
train=seasons_df[~(seasons_df['season']=='season23')]
train=train.copy()
train.drop(['Date','season'], axis=1, inplace=True)

# %%
X_train=train.drop(['label','FTR'], axis=1)
y_train=train['label']

# %%
test=seasons_df[seasons_df['season']=='season23']
test=test.copy()
test.drop(['season', 'FTR'], axis=1, inplace=True)

# %% [markdown]
# ### Scaling

# %%
scaling_columns=X_train.columns

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
test=test.copy()
test[scaling_columns]=scaler.transform(test[scaling_columns])

# %%
test = test.sort_values('Date')
unique_dates = test['Date'].unique()

# %%
# Convert the data into PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)  
y_train_tensor = torch.tensor(y_train.values, dtype=torch.long)

# %%
# Create a DataLoader for batching (optional, but useful for large datasets)
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0.001):
        """
        Args:
            patience (int): How many epochs to wait after the last improvement.
            delta (float): Minimum change in validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = float('inf')
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# Instantiate the early stopping object
early_stopping = EarlyStopping(patience=5, delta=0.001)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 256)
        self.fc2 = nn.Linear(256, 512)
        self.fc3 = nn.Linear(512, 256)
        self.fc4 = nn.Linear(256, 128)
        self.fc5 = nn.Linear(128, output_dim)
        self.dropout = nn.Dropout(0.4)  # Dropout to prevent overfitting

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x

# %%
class SimplifiedNeuralNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(SimplifiedNeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)  # Fewer neurons in the first layer
        self.fc2 = nn.Linear(128, 64)        # Second layer with fewer neurons
        self.fc3 = nn.Linear(64, output_dim) # Directly map to output classes
        self.dropout = nn.Dropout(0.2)      # Lower dropout rate (optional)

    def forward(self, x):
        x = F.relu(self.fc1(x))             # Apply ReLU after the first layer
        x = self.dropout(x)                 # Add dropout
        x = F.relu(self.fc2(x))             # Apply ReLU after the second layer
        x = self.fc3(x)                     # Output layer without activation (handled by loss function)
        return x

# %%
# Initialize the model, loss function, and optimizer
input_dim = X_train.shape[1]  # Number of features
output_dim = 3  # Number of classes (update based on your data)

#model = NeuralNetwork(input_dim, output_dim)
#class_weights = {0: 1.5, 1: 1.5, 2: 1.0}  # Inverse proportional to class frequency
#class_weights = {0: 1, 1: 1, 2: 1.0}  
#criterion = nn.CrossEntropyLoss(weight=torch.tensor(list(class_weights.values())))
# Optimizer and learning rate
#optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)  
#While Adam is effective, SGD with momentum and weight decay can sometimes generalize better for smaller datasets
#optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4) 

#optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
X_train_tensor.shape
# Out:
# torch.Size([5320, 49])

# %%
# %%time 
import ipdb

# Your dataset and DataLoader setup here
X = X_train_tensor
y = y_train_tensor
#y=y.reset_index(drop=True)

# KFold cross-validation setup
kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5 folds for cross-validation

# Initialize variables to track the performance across folds
fold_train_losses = []
fold_val_losses = []
fold_val_accuracies = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X), 1):
    print(f"Fold {fold}/{kf.get_n_splits()}")
    #ipdb.set_trace()

    # Create train and validation sets for this fold
    X_train_fold, X_val_fold = X[train_idx], X[val_idx]
    y_train_fold, y_val_fold = y[train_idx], y[val_idx]

    # Create DataLoader for this fold
    train_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(X_train_fold, y_train_fold), batch_size=16, shuffle=True) #smaller batch sizes add more noise that can act as regularisation
    val_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(X_val_fold, y_val_fold), batch_size=16, shuffle=False)

    # Initialize the model, loss function, and optimizer
    model = NeuralNetwork(input_dim=X_train_fold.shape[1], output_dim=3)  # Update output_dim based on your dataset
    #criterion = nn.CrossEntropyLoss()
    class_weights = {0: 1.5, 1: 1.5, 2: 1.0}  # Inverse proportional to class frequency
    #class_weights = {0: 1.0, 1: 1.0, 2: 1.0}  
    criterion = nn.CrossEntropyLoss(weight=torch.tensor(list(class_weights.values())))

    #optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)  # AdamW recommended over Adam
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)  # Reduce LR every 3 epochs


    # Early stopping setup
    early_stopping = EarlyStopping(patience=5, delta=0.001)

    # Training loop for this fold
    epochs = 50
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0

        # Training step
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            
        scheduler.step()  # Step the scheduler after each epoch

        # Average training loss for this epoch
        train_loss = running_loss / len(train_loader)
        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_loss:.4f}")

        # Validation step
        model.eval()
        val_loss = 0.0
        val_acc = 0.0
        with torch.no_grad():
            for X_val_batch, y_val_batch in val_loader:
                outputs = model(X_val_batch)
                loss = criterion(outputs, y_val_batch)
                val_loss += loss.item()

                _, predicted_classes = torch.max(outputs, 1)
                acc = accuracy_score(y_val_batch, predicted_classes)
                val_acc += acc

        val_loss /= len(val_loader)
        val_acc /= len(val_loader)
        print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")

        # Early stopping check
        early_stopping(val_loss)
        if early_stopping.early_stop:
            print("Early stopping triggered!")
            break

    # Track performance for this fold
    fold_train_losses.append(train_loss)
    fold_val_losses.append(val_loss)
    fold_val_accuracies.append(val_acc)

# After all folds, calculate the average performance
avg_train_loss = np.mean(fold_train_losses)
avg_val_loss = np.mean(fold_val_losses)
avg_val_acc = np.mean(fold_val_accuracies)

print(f"Average Train Loss: {avg_train_loss:.4f}")
print(f"Average Validation Loss: {avg_val_loss:.4f}")
print(f"Average Validation Accuracy: {avg_val_acc:.4f}")
# Out:
# Fold 1/5
# Epoch [1/50], Train Loss: 1.0309
# Validation Loss: 0.9963, Validation Accuracy: 0.5299
# Epoch [2/50], Train Loss: 1.0123
# Validation Loss: 0.9903, Validation Accuracy: 0.5401
# Epoch [3/50], Train Loss: 1.0044
# Validation Loss: 0.9962, Validation Accuracy: 0.5448
# Epoch [4/50], Train Loss: 0.9855
# Validation Loss: 0.9871, Validation Accuracy: 0.5392
# Epoch [5/50], Train Loss: 0.9888
# Validation Loss: 0.9878, Validation Accuracy: 0.5485
# Epoch [6/50], Train Loss: 0.9806
# Validation Loss: 0.9894, Validation Accuracy: 0.5354
# Epoch [7/50], Train Loss: 0.9826
# Validation Loss: 0.9890, Validation Accuracy: 0.5382
# Epoch [8/50], Train Loss: 0.9823
# Validation Loss: 0.9886, Validation Accuracy: 0.5382
# Epoch [9/50], Train Loss: 0.9761
# Validation Loss: 0.9884, Validation Accuracy: 0.5401
# Early stopping triggered!
# Fold 2/5
# Epoch [1/50], Train Loss: 1.0213
# Validation Loss: 1.0251, Validation Accuracy: 0.4944
# Epoch [2/50], Train Loss: 1.0090
# Validation Loss: 1.0118, Validation Accuracy: 0.4888
# Epoch [3/50], Train Loss: 1.0022
# Validation Loss: 1.0152, Validation Accuracy: 0.4935
# Epoch [4/50], Train Loss: 0.9907
# Validation Loss: 1.0114, Validation Accuracy: 0.4944
# Epoch [5/50], Train Loss: 0.9793
# Validation Loss: 1.0123, Validation Accuracy: 0.4888
# Epoch [6/50], Train Loss: 0.9796
# Validation Loss: 1.0130, Validation Accuracy: 0.4925
# Epoch [7/50], Train Loss: 0.9782
# Validation Loss: 1.0132, Validation Accuracy: 0.4916
# Early stopping triggered!
# Fold 3/5
# Epoch [1/50], Train Loss: 1.0267
# Validation Loss: 0.9987, Validation Accuracy: 0.5093
# Epoch [2/50], Train Loss: 1.0122
# Validation Loss: 1.0061, Validation Accuracy: 0.5532
# Epoch [3/50], Train Loss: 1.0060
# Validation Loss: 0.9889, Validation Accuracy: 0.5466
# Epoch [4/50], Train Loss: 0.9878
# Validation Loss: 0.9904, Validation Accuracy: 0.5448
# Epoch [5/50], Train Loss: 0.9778
# Validation Loss: 0.9912, Validation Accuracy: 0.5457
# Epoch [6/50], Train Loss: 0.9820
# Validation Loss: 0.9906, Validation Accuracy: 0.5438
# Epoch [7/50], Train Loss: 0.9773
# Validation Loss: 0.9908, Validation Accuracy: 0.5420
# Epoch [8/50], Train Loss: 0.9784
# Validation Loss: 0.9907, Validation Accuracy: 0.5420
# Early stopping triggered!
# Fold 4/5
# Epoch [1/50], Train Loss: 1.0257
# Validation Loss: 0.9914, Validation Accuracy: 0.5578
# Epoch [2/50], Train Loss: 1.0122
# Validation Loss: 0.9918, Validation Accuracy: 0.5597
# Epoch [3/50], Train Loss: 1.0093
# Validation Loss: 0.9859, Validation Accuracy: 0.5625
# Epoch [4/50], Train Loss: 0.9901
# Validation Loss: 0.9885, Validation Accuracy: 0.5485
# Epoch [5/50], Train Loss: 0.9862
# Validation Loss: 0.9864, Validation Accuracy: 0.5476
# Epoch [6/50], Train Loss: 0.9839
# Validation Loss: 0.9857, Validation Accuracy: 0.5494
# Epoch [7/50], Train Loss: 0.9829
# Validation Loss: 0.9854, Validation Accuracy: 0.5504
# Epoch [8/50], Train Loss: 0.9863
# Validation Loss: 0.9851, Validation Accuracy: 0.5504
# Early stopping triggered!
# Fold 5/5
# Epoch [1/50], Train Loss: 1.0178
# Validation Loss: 1.0176, Validation Accuracy: 0.5261
# Epoch [2/50], Train Loss: 1.0043
# Validation Loss: 1.0166, Validation Accuracy: 0.5410
# Epoch [3/50], Train Loss: 0.9967
# Validation Loss: 1.0232, Validation Accuracy: 0.5354
# Epoch [4/50], Train Loss: 0.9817
# Validation Loss: 1.0183, Validation Accuracy: 0.5252
# Epoch [5/50], Train Loss: 0.9749
# Validation Loss: 1.0183, Validation Accuracy: 0.5168
# Epoch [6/50], Train Loss: 0.9747
# Validation Loss: 1.0212, Validation Accuracy: 0.5140
# Early stopping triggered!
# Average Train Loss: 0.9788
# Average Validation Loss: 0.9997
# Average Validation Accuracy: 0.5276
# CPU times: user 5min 50s, sys: 911 ms, total: 5min 51s
# Wall time: 1min 27s

# %% [markdown]
# ### Looping through each date

# %%
# Initialize variables to track progress
predictions = []
accuracies = []
batchsizes = []
acc_batch = []
#thresholds = [0.5, 0.4, 0.5] 

for date in unique_dates:
    # Filter test data for the current date
    test_batch = test[test['Date'] == date]
    X_test_batch = test_batch.drop(columns=['label', 'Date'])
    y_test_batch = test_batch['label']
    
    # Convert test batch to tensors
    X_test_batch_tensor = torch.tensor(X_test_batch.values, dtype=torch.float32)
    y_test_batch_tensor = torch.tensor(y_test_batch.values, dtype=torch.long)
    
    # Make predictions for the current batch
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():
        y_pred_batch = model(X_test_batch_tensor)
    #uncomment this to get back to default
        _, predicted_classes = torch.max(y_pred_batch, 1)  # Get predicted class labels

    ################### comment this to get back to default
    #y_pred_proba = F.softmax(y_pred_batch, dim=1)  # Apply softmax to get probabilities
        
    # Adjust threshold for each class
    #predicted_classes = torch.argmax(y_pred_proba, dim=1)  # Default decision with max prob
        
    # Apply custom threshold for class 1 (for example, making class 1 more likely)
    #for i, threshold in enumerate(thresholds):
    #    predicted_classes[(y_pred_proba[:, i] > threshold)] = i
    ################
    
    # Collect predictions
    predictions.extend(predicted_classes.numpy())
    
    # Calculate and store metrics
    acc = accuracy_score(y_test_batch, predicted_classes.numpy())
    accuracies.append(acc)
    batchsizes.append(len(X_test_batch))
    acc_batch.append(acc * len(X_test_batch))

    print(f"Date: {date} - Accuracy: {acc:.4f} - BatchSize: {len(X_test_batch)}")

    # Update model with the current batch
    # Training mode
    model.train()  # Set the model to training mode
    
    # Concatenate current test data to the training data
    X_all = np.concatenate([X_train, X_test_batch.to_numpy()], axis=0)
    y_all = pd.concat([y_train, y_test_batch])

    # Convert to tensors
    X_all_tensor = torch.tensor(X_all, dtype=torch.float32)
    y_all_tensor = torch.tensor(y_all.values, dtype=torch.long)
    
    # Train the model with the updated data
    optimizer.zero_grad()  # Zero the gradients
    outputs = model(X_all_tensor)  # Forward pass
    loss = criterion(outputs, y_all_tensor)  # Compute loss
    loss.backward()  # Backward pass
    optimizer.step()  # Update weights
    
    # Update training data
    X_train = X_all
    y_train = y_all

# Collect all predictions for further evaluation if needed
#test['predictions'] = predictions
# Out:
# Date: 2023-08-11 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-08-12 00:00:00 - Accuracy: 0.6667 - BatchSize: 6
# Date: 2023-08-13 00:00:00 - Accuracy: 0.0000 - BatchSize: 2
# Date: 2023-08-14 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-08-18 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-08-19 00:00:00 - Accuracy: 0.8000 - BatchSize: 5
# Date: 2023-08-20 00:00:00 - Accuracy: 0.0000 - BatchSize: 2
# Date: 2023-08-21 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-08-25 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-08-26 00:00:00 - Accuracy: 0.3333 - BatchSize: 6
# Date: 2023-08-27 00:00:00 - Accuracy: 0.6667 - BatchSize: 3
# Date: 2023-09-01 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2023-09-02 00:00:00 - Accuracy: 0.3333 - BatchSize: 6
# Date: 2023-09-03 00:00:00 - Accuracy: 1.0000 - BatchSize: 3
# Date: 2023-09-16 00:00:00 - Accuracy: 0.8571 - BatchSize: 7
# Date: 2023-09-17 00:00:00 - Accuracy: 0.5000 - BatchSize: 2
# Date: 2023-09-18 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2023-09-23 00:00:00 - Accuracy: 0.6000 - BatchSize: 5
# Date: 2023-09-24 00:00:00 - Accuracy: 0.6000 - BatchSize: 5
# Date: 2023-09-30 00:00:00 - Accuracy: 0.3750 - BatchSize: 8
# Date: 2023-10-01 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2023-10-02 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-10-03 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-10-07 00:00:00 - Accuracy: 0.8333 - BatchSize: 6
# Date: 2023-10-08 00:00:00 - Accuracy: 0.2500 - BatchSize: 4
# Date: 2023-10-21 00:00:00 - Accuracy: 0.6250 - BatchSize: 8
# Date: 2023-10-22 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-10-23 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-10-27 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-10-28 00:00:00 - Accuracy: 0.2500 - BatchSize: 4
# Date: 2023-10-29 00:00:00 - Accuracy: 0.8000 - BatchSize: 5
# Date: 2023-11-04 00:00:00 - Accuracy: 0.4286 - BatchSize: 7
# Date: 2023-11-05 00:00:00 - Accuracy: 0.0000 - BatchSize: 2
# Date: 2023-11-06 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-11-11 00:00:00 - Accuracy: 0.6000 - BatchSize: 5
# Date: 2023-11-12 00:00:00 - Accuracy: 0.6000 - BatchSize: 5
# Date: 2023-11-25 00:00:00 - Accuracy: 0.4286 - BatchSize: 7
# Date: 2023-11-26 00:00:00 - Accuracy: 0.5000 - BatchSize: 2
# Date: 2023-11-27 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-12-02 00:00:00 - Accuracy: 1.0000 - BatchSize: 5
# Date: 2023-12-03 00:00:00 - Accuracy: 0.4000 - BatchSize: 5
# Date: 2023-12-05 00:00:00 - Accuracy: 1.0000 - BatchSize: 2
# Date: 2023-12-06 00:00:00 - Accuracy: 0.8333 - BatchSize: 6
# Date: 2023-12-07 00:00:00 - Accuracy: 0.0000 - BatchSize: 2
# Date: 2023-12-09 00:00:00 - Accuracy: 0.1667 - BatchSize: 6
# Date: 2023-12-10 00:00:00 - Accuracy: 0.7500 - BatchSize: 4
# Date: 2023-12-15 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2023-12-16 00:00:00 - Accuracy: 0.2500 - BatchSize: 4
# Date: 2023-12-17 00:00:00 - Accuracy: 0.5000 - BatchSize: 4
# Date: 2023-12-21 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2023-12-22 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2023-12-23 00:00:00 - Accuracy: 0.1667 - BatchSize: 6
# Date: 2023-12-24 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2023-12-26 00:00:00 - Accuracy: 0.4000 - BatchSize: 5
# Date: 2023-12-27 00:00:00 - Accuracy: 0.6667 - BatchSize: 3
# Date: 2023-12-28 00:00:00 - Accuracy: 0.5000 - BatchSize: 2
# Date: 2023-12-30 00:00:00 - Accuracy: 0.5000 - BatchSize: 6
# Date: 2023-12-31 00:00:00 - Accuracy: 0.5000 - BatchSize: 2
# Date: 2024-01-01 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-01-02 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2024-01-12 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-01-13 00:00:00 - Accuracy: 1.0000 - BatchSize: 2
# Date: 2024-01-14 00:00:00 - Accuracy: 0.0000 - BatchSize: 2
# Date: 2024-01-20 00:00:00 - Accuracy: 1.0000 - BatchSize: 2
# Date: 2024-01-21 00:00:00 - Accuracy: 0.5000 - BatchSize: 2
# Date: 2024-01-22 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2024-01-30 00:00:00 - Accuracy: 0.4000 - BatchSize: 5
# Date: 2024-01-31 00:00:00 - Accuracy: 1.0000 - BatchSize: 3
# Date: 2024-02-01 00:00:00 - Accuracy: 1.0000 - BatchSize: 2
# Date: 2024-02-03 00:00:00 - Accuracy: 0.8000 - BatchSize: 5
# Date: 2024-02-04 00:00:00 - Accuracy: 0.5000 - BatchSize: 4
# Date: 2024-02-05 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-02-10 00:00:00 - Accuracy: 0.7143 - BatchSize: 7
# Date: 2024-02-11 00:00:00 - Accuracy: 0.5000 - BatchSize: 2
# Date: 2024-02-12 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-02-17 00:00:00 - Accuracy: 0.5714 - BatchSize: 7
# Date: 2024-02-18 00:00:00 - Accuracy: 1.0000 - BatchSize: 2
# Date: 2024-02-19 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2024-02-20 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-02-21 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-02-24 00:00:00 - Accuracy: 0.6667 - BatchSize: 6
# Date: 2024-02-25 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-02-26 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2024-03-02 00:00:00 - Accuracy: 0.5714 - BatchSize: 7
# Date: 2024-03-03 00:00:00 - Accuracy: 1.0000 - BatchSize: 2
# Date: 2024-03-04 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-03-09 00:00:00 - Accuracy: 0.4000 - BatchSize: 5
# Date: 2024-03-10 00:00:00 - Accuracy: 0.2500 - BatchSize: 4
# Date: 2024-03-11 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-03-13 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-03-16 00:00:00 - Accuracy: 0.0000 - BatchSize: 3
# Date: 2024-03-17 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2024-03-30 00:00:00 - Accuracy: 0.5000 - BatchSize: 8
# Date: 2024-03-31 00:00:00 - Accuracy: 0.5000 - BatchSize: 2
# Date: 2024-04-02 00:00:00 - Accuracy: 0.2000 - BatchSize: 5
# Date: 2024-04-03 00:00:00 - Accuracy: 0.6667 - BatchSize: 3
# Date: 2024-04-04 00:00:00 - Accuracy: 1.0000 - BatchSize: 2
# Date: 2024-04-06 00:00:00 - Accuracy: 0.5714 - BatchSize: 7
# Date: 2024-04-07 00:00:00 - Accuracy: 0.3333 - BatchSize: 3
# Date: 2024-04-13 00:00:00 - Accuracy: 0.3333 - BatchSize: 6
# Date: 2024-04-14 00:00:00 - Accuracy: 0.0000 - BatchSize: 3
# Date: 2024-04-15 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-04-20 00:00:00 - Accuracy: 1.0000 - BatchSize: 3
# Date: 2024-04-21 00:00:00 - Accuracy: 1.0000 - BatchSize: 4
# Date: 2024-04-23 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-04-24 00:00:00 - Accuracy: 0.5000 - BatchSize: 4
# Date: 2024-04-25 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-04-27 00:00:00 - Accuracy: 0.2857 - BatchSize: 7
# Date: 2024-04-28 00:00:00 - Accuracy: 1.0000 - BatchSize: 3
# Date: 2024-05-02 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-05-03 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-05-04 00:00:00 - Accuracy: 0.6000 - BatchSize: 5
# Date: 2024-05-05 00:00:00 - Accuracy: 0.6667 - BatchSize: 3
# Date: 2024-05-06 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-05-11 00:00:00 - Accuracy: 0.6250 - BatchSize: 8
# Date: 2024-05-12 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-05-13 00:00:00 - Accuracy: 0.0000 - BatchSize: 1
# Date: 2024-05-14 00:00:00 - Accuracy: 1.0000 - BatchSize: 1
# Date: 2024-05-15 00:00:00 - Accuracy: 0.0000 - BatchSize: 2
# Date: 2024-05-19 00:00:00 - Accuracy: 0.7000 - BatchSize: 10

# %%
# Print classification report
from sklearn.metrics import classification_report
print(classification_report(test['label'], predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.63      0.58       123
#            1       0.21      0.10      0.13        82
#            2       0.66      0.74      0.70       175
#
#     accuracy                           0.57       380
#    macro avg       0.47      0.49      0.47       380
# weighted avg       0.52      0.57      0.54       380

# %%
# Create the plot
plt.plot(accuracies , marker='o', color='blue', label='Accuracy over Epochs')  # Add markers for clarity

# Add labels and title
plt.title('Model Accuracy Over Time')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)  # Optional: Add a grid for better visualization
plt.legend()  # Optional: Add legend
plt.show()  # Display the plot

# %%
# Assuming accuracies is a list of accuracy values over epochs
epochs = np.arange(len(accuracies))  # Epochs are the x-values

# Calculate the slope using numpy's polyfit
slope, intercept = np.polyfit(epochs, accuracies, 1)

# Create the plot for the accuracy values
plt.plot(accuracies, marker='o', color='blue', label='Accuracy over Epochs')  # Add markers for clarity

# Plot the line representing the slope in red
plt.plot(epochs, slope * epochs + intercept, color='red', label=f'Slope: {slope:.4f}')

# Add labels and title
plt.title('Model Accuracy Over Time')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)  # Optional: Add a grid for better visualization

# Optional: Add legend
plt.legend()

# Display the plot
plt.show()

# %%
# Generate confusion matrix
cm = confusion_matrix(test['label'], predictions)



# Create a heatmap for the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[0, 1, 2], yticklabels=[0, 1, 2])

# Add labels
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

# Show plot
plt.show()

# %%
# Generate confusion matrix
cm = confusion_matrix(test['label'], predictions)



# Create a heatmap for the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[0, 1, 2], yticklabels=[0, 1, 2])

# Add labels
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

# Show plot
plt.show()
